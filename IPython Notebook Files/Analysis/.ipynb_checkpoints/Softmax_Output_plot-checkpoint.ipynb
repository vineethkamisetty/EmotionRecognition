# %%
import pandas as pd
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import tensorflow
import tflearn
import numpy as np
import six
from tflearn import *

EMOTIONS = ['angry','fearful', 'happy', 'sad', 'surprised', 'neutral']
def network():
    network = input_data(shape=[None, 48, 48, 1])

    network = conv_2d(network, 32, 3, activation='relu')
    network = conv_2d(network, 32, 5, activation='relu')
    network = max_pool_2d(network, 2, strides=2)
    network = dropout(network, 0.3)
    network = local_response_normalization(network)
    network = conv_2d(network, 64, 3, activation='relu')
    network = conv_2d(network, 64, 5, activation='relu')
    network = max_pool_2d(network, 2, strides=2)
    network = dropout(network, 0.3)
    network = local_response_normalization(network)
    network = conv_2d(network, 128, 3, activation='relu')
    network = conv_2d(network, 128, 5, activation='relu') 
    network = max_pool_2d(network, 2, strides=2)
    network = dropout(network, 0.3)
    network = local_response_normalization(network)
    network = fully_connected(network, 1024, activation='relu')
    network = dropout(network, 0.7)  # need to change if needed 0.7 -> 0.5
    network = fully_connected(network, 1024, activation='relu')
    network = dropout(network, 0.7)  # need to change if needed 0.7 -> 0.5
    network = fully_connected(network, len(EMOTIONS), activation='softmax')

    network = regression(network,
                         optimizer='adam',
                         loss='categorical_crossentropy',
                         learning_rate=0.001)  # need to check with different learning rate

    model = tflearn.DNN(network, tensorboard_verbose=3)
    return model

def getrawnetwork():
    return network()

def getsavednetwork(savepath='../../SavedModels/model_2b0.tfl'):
    model = getrawnetwork()
    model.load(savepath)
    return model
    
    
model = getsavednetwork()
print("loaded network")


images_train = np.load("../../RafD/RaFD_images_train.npy")
pixels = images_train[105][0]/255

image48 = pixels.reshape(1, 48, 48, 1)

result = model.predict(image48)
EMOTIONS = ['angry','fearful', 'happy', 'sad', 'surprised', 'neutral']
plt.xlabel(EMOTIONS[result[0].index(max(result[0]))], color='#53b3cb',fontsize=12)
plt.imshow(image48.reshape(48,48), cmap = cm.gray)

for i in result[0]:
    print(int(i*100),end="  ")

fig = plt.figure(figsize=(20,20))
#input_img = X[i:(i+1),:,:,:]
ax = fig.add_subplot(6,6,1)
y_prob = np.array(result[0])
ax.bar(np.arange(0,6), y_prob, color=['red','blue','green','black','yellow','orange'],alpha=0.5)
ax.set_xticks(np.arange(0.0,6.5,1))
ax.set_xticklabels(EMOTIONS, rotation=90, fontsize=10)
ax.set_yticks(np.arange(0.0,1.1,0.5))
plt.tight_layout() 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# NotFoundError: Key val_loss_2 not found in checkpoint
# 	 [[Node: save_6/RestoreV2_128 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_6/Const_0, save_6/RestoreV2_128/tensor_names, save_6/RestoreV2_128/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-2-d504389c3649> in <module>()
#      54
#      55
# ---> 56 model = getsavednetwork()
#      57 print("loaded network")
#      58
#
# <ipython-input-2-d504389c3649> in getsavednetwork(savepath)
#      50 def getsavednetwork(savepath='../../SavedModels/model_2b0.tfl'):
#      51     model = getrawnetwork()
# ---> 52     model.load(savepath)
#      53     return model
#      54
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tflearn\models\dnn.py in load(self, model_file, weights_only, **optargs)
#     276                      created for the restored variables.
#     277         """
# --> 278         self.trainer.restore(model_file, weights_only, **optargs)
#     279         self.session = self.trainer.session
#     280         self.predictor = Evaluator([self.net],
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tflearn\helpers\trainer.py in restore(self, model_file, trainable_variable_only, variable_name_map, scope_for_restore, create_new_session, verbose)
#     447             restorer.restore(self.session, model_file)
#     448         elif not trainable_variable_only:
# --> 449             self.restorer.restore(self.session, model_file)
#     450         else:
#     451             self.restorer_trainvars.restore(self.session, model_file)
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1437       return
#    1438     sess.run(self.saver_def.restore_op_name,
# -> 1439              {self.saver_def.filename_tensor_name: save_path})
#    1440
#    1441   @staticmethod
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: Key val_loss_2 not found in checkpoint
# 	 [[Node: save_6/RestoreV2_128 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_6/Const_0, save_6/RestoreV2_128/tensor_names, save_6/RestoreV2_128/shape_and_slices)]]
#
# Caused by op 'save_6/RestoreV2_128', defined at:
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\ipykernel\__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tornado\ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-d504389c3649>", line 56, in <module>
#     model = getsavednetwork()
#   File "<ipython-input-2-d504389c3649>", line 51, in getsavednetwork
#     model = getrawnetwork()
#   File "<ipython-input-2-d504389c3649>", line 48, in getrawnetwork
#     return network()
#   File "<ipython-input-2-d504389c3649>", line 44, in network
#     model = tflearn.DNN(network, tensorboard_verbose=3)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tflearn\models\dnn.py", line 64, in __init__
#     best_val_accuracy=best_val_accuracy)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 145, in __init__
#     keep_checkpoint_every_n_hours=keep_checkpoint_every_n_hours)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1051, in __init__
#     self.build()
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1081, in build
#     restore_sequentially=self._restore_sequentially)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 402, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 242, in restore_op
#     [spec.tensor.dtype])[0])
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 668, in restore_v2
#     dtypes=dtypes, name=name)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "C:\Users\Chaitanya Maddala\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key val_loss_2 not found in checkpoint
# 	 [[Node: save_6/RestoreV2_128 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_6/Const_0, save_6/RestoreV2_128/tensor_names, save_6/RestoreV2_128/shape_and_slices)]]
